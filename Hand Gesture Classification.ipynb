# %% [markdown]
# # Hand Gesture Classification

# %%
# Install Tensorflow
#!pip install tensorflow

import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# TensorFlow version: 2.15.0

# %%
# Zero dimensional tensor
zero_dim_tensor = tf.constant(20)
print(zero_dim_tensor)

# One dimensional tensor
one_dim_tensor = tf.constant([12, 20, 53, 26, 11, 56])
print(one_dim_tensor)

# Two dimensional tensor
two_dim_array = [[3, 6, 7, 5], 
                 [9, 2, 3, 4],
                 [7, 1, 10,6],
                 [0, 8, 11,2]]

two_dim_tensor = tf.constant(two_dim_array)
print(two_dim_tensor)
# Out:
# tf.Tensor(20, shape=(), dtype=int32)
# tf.Tensor([12 20 53 26 11 56], shape=(6,), dtype=int32)
# tf.Tensor(
# [[ 3  6  7  5]
#  [ 9  2  3  4]
#  [ 7  1 10  6]
#  [ 0  8 11  2]], shape=(4, 4), dtype=int32)

# %% [markdown]
# # Load Data

# %%
from tensorflow.keras.datasets import cifar10 as cf10
import numpy as np
import matplotlib.pyplot as plt

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *
from test_utils import summary, comparator

# %matplotlib inline
np.random.seed(1)

# %%
train_images, train_labels, test_images, test_labels, classes = load_signs_dataset()

# %% [markdown]
# ## EDA

# %%
# Normalize the x, then convert the output from numerical to categorical
from tensorflow.keras.utils import to_categorical

# Data normalization
x_train = train_images / 255
x_test = test_images / 255

# One-hot encode the labels
from tensorflow.keras.utils import to_categorical
y_train = train_labels.T
y_test = test_labels.T
y_train = to_categorical(y_train, len(class_names))
y_test = to_categorical(y_test, len(class_names))

print ("number of training examples = " + str(x_train.shape[0]))
print ("number of test examples = " + str(x_test.shape[0]))
print ("x_train shape: " + str(x_train.shape))
print ("y_train shape: " + str(y_train.shape))
print ("x_test shape: " + str(x_test.shape))
print ("y_test shape: " + str(y_test.shape))
print ("The proportion of the train data is " + str(round((len(x_train)/(len(x_train)+len(x_test)))*100,2)) + "%")
# Out:
# number of training examples = 1080
# number of test examples = 120
# x_train shape: (1080, 64, 64, 3)
# y_train shape: (1080, 6)
# x_test shape: (120, 64, 64, 3)
# y_test shape: (120, 6)
# The proportion of the train data is 90.0%

# %%
# 1. Function for showing images
def show_images(train_images, 
                class_names, 
                train_labels, 
                nb_samples = 12, nb_row = 4):
    
    plt.figure(figsize=(12, 12))
    for i in range(nb_samples):
        plt.subplot(nb_row, nb_row, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(train_images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[y_train[i][0]])
    plt.show()

# %%
# Visualize some sample images from the dataset
class_names = ['0', '1', '2', '3', '4', '5']

show_images(train_images, class_names, y_train)

# %%
# Visualize a sample images from the dataset
index = 91
plt.imshow(train_images[index]) #display sample training image
plt.show()

# %% [markdown]
# # 5 Model

# %% [markdown]
# ## 5.1 Architecture

# %%
# GRADED FUNCTION: convolutional_model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters = 8, kernel_size = 4, strides  = 1, padding = 'same', input_shape = (64, 64, 3)),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling2D(pool_size = 8, strides  = 8, padding = 'same'),
    tf.keras.layers.Conv2D(filters = 16, kernel_size = 2, strides  = 1, padding = 'same'),
    tf.keras.layers.ReLU(),
    tf.keras.layers.MaxPooling2D(pool_size = 4, strides  = 4, padding = 'same'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units = 6, activation = 'softmax')
    ])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 8)           │             392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 64, 64, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 8, 8, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 8, 8, 16)            │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 8, 8, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 2, 2, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 6)                   │             390 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,310 (5.12 KB)
#  Trainable params: 1,310 (5.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ![Arch3.png](Arch3.png)

# %%
from tensorflow.keras.metrics import Precision, Recall

BATCH_SIZE = 64
EPOCHS = 100

METRICS = metrics=['accuracy', 
                   Precision(name='precision'),
                   Recall(name='recall')]

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics = METRICS)

# Train the model
training_history = model.fit(x_train, y_train, 
                    epochs=EPOCHS, batch_size=BATCH_SIZE,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.1753 - loss: 0.6635 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2000 - val_loss: 0.5208 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2142 - loss: 0.4922 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2417 - val_loss: 0.4591 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2381 - loss: 0.4545 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1167 - val_loss: 0.4517 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1511 - loss: 0.4509 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1333 - val_loss: 0.4509 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.1887 - loss: 0.4502 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1250 - val_loss: 0.4502 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1932 - loss: 0.4494 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1917 - val_loss: 0.4498 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2196 - loss: 0.4488 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1500 - val_loss: 0.4494 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2220 - loss: 0.4484 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1750 - val_loss: 0.4487 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2426 - loss: 0.4475 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2250 - val_loss: 0.4483 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3052 - loss: 0.4469 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2417 - val_loss: 0.4477 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2889 - loss: 0.4461 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2167 - val_loss: 0.4468 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.2845 - loss: 0.4455 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1917 - val_loss: 0.4459 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3131 - loss: 0.4435 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2667 - val_loss: 0.4451 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3225 - loss: 0.4430 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2250 - val_loss: 0.4436 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3488 - loss: 0.4416 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2250 - val_loss: 0.4423 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3778 - loss: 0.4402 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2917 - val_loss: 0.4411 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3459 - loss: 0.4374 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2917 - val_loss: 0.4391 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3943 - loss: 0.4346 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3167 - val_loss: 0.4372 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4002 - loss: 0.4325 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3667 - val_loss: 0.4345 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4238 - loss: 0.4293 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3167 - val_loss: 0.4323 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4339 - loss: 0.4268 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3250 - val_loss: 0.4305 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4321 - loss: 0.4235 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3750 - val_loss: 0.4265 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3882 - loss: 0.4214 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3583 - val_loss: 0.4216 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4250 - loss: 0.4141 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3917 - val_loss: 0.4184 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3814 - loss: 0.4110 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.4000 - val_loss: 0.4128 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4265 - loss: 0.4051 - precision: 0.7222 - recall: 0.0024 - val_accuracy: 0.4333 - val_loss: 0.4079 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.
100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8726 - loss: 0.1604 - precision: 0.8949 - recall: 0.8376 - val_accuracy: 0.7583 - val_loss: 0.2308 - val_precision: 0.7928 - val_recall: 0.7333
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8616 - loss: 0.1636 - precision: 0.8885 - recall: 0.8233 - val_accuracy: 0.7667 - val_loss: 0.2160 - val_precision: 0.7818 - val_recall: 0.7167
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8467 - loss: 0.1664 - precision: 0.8805 - recall: 0.8280 - val_accuracy: 0.7917 - val_loss: 0.2173 - val_precision: 0.8091 - val_recall: 0.7417
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8659 - loss: 0.1618 - precision: 0.8964 - recall: 0.8360 - val_accuracy: 0.7750 - val_loss: 0.2147 - val_precision: 0.7965 - val_recall: 0.7500
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8527 - loss: 0.1630 - precision: 0.8872 - recall: 0.8220 - val_accuracy: 0.7750 - val_loss: 0.2159 - val_precision: 0.8000 - val_recall: 0.7333
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8544 - loss: 0.1581 - precision: 0.8950 - recall: 0.8249 - val_accuracy: 0.7583 - val_loss: 0.2169 - val_precision: 0.8056 - val_recall: 0.7250
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8675 - loss: 0.1612 - precision: 0.8994 - recall: 0.8413 - val_accuracy: 0.7417 - val_loss: 0.2254 - val_precision: 0.7909 - val_recall: 0.7250

# %%
def show_performance_curve(training_result, metric, metric_label):
    import numpy as np
    import matplotlib.pyplot as plt
    
    train_perf = training_result.history[str(metric)]
    validation_perf = training_result.history['val_'+str(metric)]
    intersection_indices = np.argwhere(np.isclose(train_perf, validation_perf, atol=1e-2)).flatten()
    
    # Check if intersection_indices is not empty
    if intersection_indices.size > 0:
        intersection_idx = intersection_indices[0]
        intersection_value = train_perf[intersection_idx]
    else:
        # Handle the case where no intersection is found
        intersection_idx = None
        intersection_value = None
        print("No intersection found within the given tolerance.")
    
    plt.plot(train_perf, label=metric_label + ' (Training)')
    plt.plot(validation_perf, label=metric_label + ' (Validation)')
    if intersection_idx is not None:
        plt.plot(intersection_idx, intersection_value, 'ro')  # Mark the intersection point
        plt.text(intersection_idx, intersection_value, f'Intersection at index {intersection_idx}', fontsize=9)
    plt.title('Training and Validation ' + metric_label)
    plt.xlabel('Epochs')
    plt.ylabel(metric_label)
    plt.legend()
    plt.show()

# %%
show_performance_curve(training_history, 'accuracy', 'accuracy')
show_performance_curve(training_history, 'recall', 'recall')
show_performance_curve(training_history, 'precision', 'precision')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Obtain the model's predictions on the test dataset
test_predictions = model.predict(x_test)

# Convert predictions from probabilities to class labels
test_predicted_labels = np.argmax(test_predictions, axis=1)

# Convert one-hot encoded true labels back to class labels
test_true_labels = np.argmax(y_test, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(test_true_labels, test_predicted_labels)

# Create a ConfusionMatrixDisplay instance
cmd = ConfusionMatrixDisplay(confusion_matrix=cm)

# Plot the confusion matrix
cmd.plot(include_values=True, cmap='viridis', ax=None, xticks_rotation='horizontal')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
